# %%
import pandas as pd

# %%
# import json
# with open("/Users/jun_yu/Downloads/recall_videos.json", 'r') as file:
#     json_data = file.read()

# data = json.loads(json_data)
# print(type(data))

# for i in data:
#     print(type(i))
#     for k,v in i.items():
#         if k == 'recall_list':
#             print(type(v))
# #             print(v.keys())

# %%
from IPython.core.interactiveshell import InteractiveShell
# Set shell to show all lines of output
InteractiveShell.ast_node_interactivity = 'all'

# %%
import json
books = []
with open('/Users/jun_yu/Downloads/wikipedia-data-science-master/data/found_books_filtered.ndjson', 'r') as fin:
    # Append each line to the books
    books = [json.loads(l) for l in fin]

# %%
for i in  range(1):
    print(books[i])
# Out:
# ['Freud: His Life and His Mind', {'1': '< !-- See Wikipedia:WikiProject_Books -- >', 'name': 'Freud: His Life and His Mind', 'image': 'File:Freud, His Life and His Mind (first edition).jpg', 'caption': 'Cover of the first edition', 'author': 'Helen Walker Puner', 'country': 'United States', 'language': 'English', 'subject': 'Sigmund Freud', 'publisher': 'Dell Publishing', 'pub_date': '1947', 'media_type': 'Print (Hardcover and Paperback)', 'pages': '288 (1959 edition)', 'isbn': '978-1560006114'}, ['Sigmund Freud', 'Dell Publishing', 'Hardcover', 'Paperback', 'Sigmund Freud', 'Erich Fromm', 'Dell Publishing', 'Anna Freud', 'Ernest Jones', 'Carl Jung', 'Wilhelm Stekel', 'Fritz Wittels', 'Maurice English', 'The Nation', 'Frederick Crews', 'The New York Review of Books', 'Peter Gay', 'Freud: A Life for Our Time', 'The Life and Work of Sigmund Freud', 'Louis Breger', 'Wilhelm Fliess', 'Freud family', 'Cambridge University Press', 'John Wiley  &  Sons', 'Dell Publishing', 'Papermac', 'The Nation', 'The New York Review of Books', 'Category:1947 books', 'Category:Books about Sigmund Freud', 'Category:English-language books'], ['https://www.ebsco.com', 'http://www.nybooks.com/articles/2017/02/23/freud-whats-left/'], '2018-04-03T19:57:42Z', 3069]

# %%
# Remove non-book articles
books_with_wikipedia = [book for book in books if 'Wikipedia:' in book[0]]
books = [book for book in books if 'Wikipedia:' not in book[0]]
print(f'Found {len(books)} books.')
# Out:
# Found 37020 books.

# %%
[book[0] for book in books_with_wikipedia][:5]
# Out:
# []

# %%
n = 21
books[n][0], 
books[n][1], 
books[n][2][:5], 
books[n][3][:5], 
books[n][3][:5], 
books[n][4], 
books[n][5]
# Out:
# ('Limonov (novel)',)
# ({'author': 'Emmanuel Carrère',
#   'country': 'France',
#   'english_pub_date': '2014',
#   'isbn': '978-2-8180-1405-9',
#   'language': 'French',
#   'name': 'Limonov',
#   'pages': '488',
#   'pub_date': '2011',
#   'publisher': 'P.O.L.',
#   'translator': 'John Lambert'},)
# (['Emmanuel Carrère',
#   'biographical novel',
#   'Emmanuel Carrère',
#   'Eduard Limonov',
#   'Prix de la langue française'],)
# (['http://www.lefigaro.fr/flash-actu/2011/10/05/97001-20111005FILWWW00615-le-prix-de-la-langue-francaise-a-e-carrere.php',
#   'http://www.lexpress.fr/culture/livre/emmanuel-carrere-prix-renaudot-2011_1046819.html',
#   'http://limonow.de/carrere/index.html',
#   'http://www.tout-sur-limonov.fr/222318809'],)
# (['http://www.lefigaro.fr/flash-actu/2011/10/05/97001-20111005FILWWW00615-le-prix-de-la-langue-francaise-a-e-carrere.php',
#   'http://www.lexpress.fr/culture/livre/emmanuel-carrere-prix-renaudot-2011_1046819.html',
#   'http://limonow.de/carrere/index.html',
#   'http://www.tout-sur-limonov.fr/222318809'],)
# ('2018-08-18T02:03:21Z',)
# 1437

# %%
# 将所有book 进行序列编号  
book_index = {book[0]: idx for idx, book in enumerate(books)}
index_book = {idx: book for book, idx in book_index.items()}

# %%
len(index_book)
# Out:
# 37020

# %%
# book 和 index 映射 
book_index['Anna Karenina']
index_book[22494]
# Out:
# 22494
# 'Anna Karenina'

# %%
from itertools import chain
# 拼合所有的list book [book1, book2, book3]
wikilinks = list(chain(*[book[2] for book in books]))
print("There are {len(set(wikilinks))} unique wikilinks.")
# Out:
# There are {len(set(wikilinks))} unique wikilinks.

# %%
wikilinks[:10]
# Out:
# ['Sigmund Freud',
#  'Dell Publishing',
#  'Hardcover',
#  'Paperback',
#  'Sigmund Freud',
#  'Erich Fromm',
#  'Dell Publishing',
#  'Anna Freud',
#  'Ernest Jones',
#  'Carl Jung']

# %%
from collections import Counter, OrderedDict

def count_items(l):
    """Return ordered dictionary of counts of objects in `l`"""
    # Create a counter object
    counts = Counter(l)
    # Sort by highest count first and place in ordered dictionary
    counts = sorted(counts.items(), key = lambda x: x[1], reverse = True)
    counts = OrderedDict(counts)
    return counts

# %%
# Find set of wikilinks for each book and convert to a flattened list
# 拼合所有book[2]的内容  
unique_wikilinks = list(chain(*[list(set(book[2])) for book in books]))

# %%
# unique_wikilinks
print(len(unique_wikilinks))
# Out:
# 1030651

# %%
wikilink_counts = count_items(unique_wikilinks)

# %%
print(type(wikilink_counts))
wikilink_counts
# Out:
# <class 'collections.OrderedDict'>
# OrderedDict([('Hardcover', 7489),
#              ('Paperback', 7311),
#              ('Wikipedia:WikiProject Books', 6043),
#              ('Wikipedia:WikiProject Novels', 6015),
#              ('English language', 4185),
#              ('United States', 3060),
#              ('Science fiction', 3030),
#              ('The New York Times', 2727),
#              ('science fiction', 2502),
#              ('novel', 1979),
#              ('Publishers Weekly', 1774),
#              ('The Guardian', 1630),
#              ('paperback', 1429),
#              ('Kirkus Reviews', 1335),
#              ('Category:American science fiction novels', 1289),
#              ('fantasy', 1264),
#              ('hardcover', 1159),
#              ('Category:American novels adapted into films', 1139),
#              ('HarperCollins', 1102),
#              ("Children's literature", 1100),
#              ('Random House', 1085),
#              ('Fantasy novel', 1080),
#              ('Category:Debut novels', 1072),
#              ('Category:American fantasy novels', 1036),
#              ('Novel', 1004),
#              ('New York Times', 996),
#              ('Category:American young adult novels', 956),
#              ('World War II', 947),
#              ('Hardback', 924),
#              ('Category:HarperCollins books', 890),
#              ('Category:British novels adapted into films', 849),
#              ('Doubleday (publisher)', 799),
#              ('Simon  &  Schuster', 790),
#              ('Category:English-language books', 773),
#              ('New York City', 773),
#              ('United Kingdom', 764),
#              ('Fantasy', 739),
#              ('Non-fiction', 737),
#              ('London', 712),
#              ('Penguin Books', 670),
#              ('Doctor Who', 652),
#              ('Historical novel', 640),
#              ('Category:American non-fiction books', 635),
#              ('The Independent', 632),
#              ('Category:Novels first published in serial form', 630),
#              ('Los Angeles Times', 628),
#              ('The Washington Post', 628),
#              ("Category:American children's novels", 623),
#              ('Alfred A. Knopf', 623),
#              ('Fantasy fiction', 612),
#              ('Tor Books', 608),
#              ('Thriller (genre)', 595),
#              ('Category:Doubleday (publisher) books', 592),
#              ('anthology', 570),
#              ('Mystery novel', 565),
#              ('Horror fiction', 561),
#              ('Mystery fiction', 559),
#              ('BBC', 552),
#              ('Booklist', 538),
#              ('Crime novel', 530),
#              ('Australia', 528),
#              ('Macmillan Publishers', 515),
#              ('Oxford University Press', 514),
#              ('India', 499),
#              ('The New Yorker', 498),
#              ('Viking Press', 491),
#              ("Category:British children's novels", 488),
#              ('Dungeons  &  Dragons', 482),
#              ('Amazon.com', 480),
#              ('The Daily Telegraph', 479),
#              ('Del Rey Books', 477),
#              ('Category:Tor Books books', 469),
#              ('World War I', 468),
#              ('School Library Journal', 464),
#              ('Detective fiction', 463),
#              ('short stories', 462),
#              ('Category:Novels set in New York City', 454),
#              ('debut novel', 453),
#              ('Category:Novels set in London', 446),
#              ('Soviet Union', 444),
#              ('Ace Books', 439),
#              ('Category:American picture books', 437),
#              ('Category:Alfred A. Knopf books', 426),
#              ('Internet Archive', 419),
#              ('Category:British science fiction novels', 418),
#              ('Category:Historical novels', 415),
#              ('Time (magazine)', 409),
#              ('Galaxy Science Fiction', 409),
#              ('Fiction', 408),
#              ('role-playing game', 408),
#              ('Bantam Books', 408),
#              ("Category:Children's fantasy novels", 407),
#              ("St. Martin's Press", 407),
#              ('young adult fiction', 404),
#              ('historical novel', 400),
#              ('Library Journal', 399),
#              ('Young adult fiction', 399),
#              ('French language', 397),
#              ('Role-playing game', 396),
#              ('Category:Novels adapted into television programs', 393),
#              ('The Times', 392),
#              ('WorldCat', 392),
#              ('short story', 391),
#              ('The New York Times Book Review', 387),
#              ('Category:Del Rey books', 387),
#              ('The Observer', 384),
#              ('Ballantine Books', 381),
#              ('Crime fiction', 380),
#              ('France', 375),
#              ('Entertainment Weekly', 375),
#              ('BBC Radio 4', 372),
#              ('science fiction on television', 371),
#              ('Category:Sequel novels', 371),
#              ('USA Today', 367),
#              ('audiobook', 366),
#              ('Category:2007 books', 365),
#              ('Category:Fantasy novels', 363),
#              ('American Library Association', 362),
#              ('e-book', 360),
#              ('novella', 360),
#              ('Canada', 359),
#              ('protagonist', 359),
#              ('non-fiction', 358),
#              ('Category:2008 books', 354),
#              ('Victor Gollancz Ltd', 353),
#              ('fantasy novel', 349),
#              ('Jonathan Cape', 341),
#              ('Category:American historical novels', 341),
#              ('Isaac Asimov', 337),
#              ('The New York Times Best Seller list', 335),
#              ('Category:Fantasy short story collections', 334),
#              ('Category:2006 books', 330),
#              ('Paris', 328),
#              ('Category:2005 books', 328),
#              ('Category:Viking Press books', 327),
#              ('Romance novel', 326),
#              ('memoir', 326),
#              ('Category:Random House books', 325),
#              ('Category:2009 books', 322),
#              ('Category:English novels', 321),
#              ('Category:World War II novels', 321),
#              ('Category:2007 American novels', 321),
#              ('Adventure novel', 318),
#              ("children's literature", 317),
#              ('Category:Ace Books books', 314),
#              ('Swedish language', 314),
#              ('Pocket Books', 313),
#              ('Category:American thriller novels', 312),
#              ('Autobiography', 311),
#              ('BBC Books', 306),
#              ('German language', 305),
#              ('Category:2010 non-fiction books', 303),
#              ('Category:Dystopian novels', 299),
#              ('TSR, Inc.', 299),
#              ("G. P. Putnam's Sons", 298),
#              ('Project Gutenberg', 298),
#              ('Category:2004 books', 292),
#              ('Category:Works published under a pseudonym', 291),
#              ('Russian language', 291),
#              ('Historical fiction', 289),
#              ('L. Sprague de Camp', 288),
#              ('Biography', 287),
#              ('Memoir', 287),
#              ('Young adult novel', 284),
#              ('Sweden', 283),
#              ('autobiography', 282),
#              ('Fantasy literature', 281),
#              ('NPR', 281),
#              ('Category:2006 American novels', 281),
#              ('Category:Science fiction anthologies', 281),
#              ('Category:Jonathan Cape books', 280),
#              ('Category:2011 books', 279),
#              ('Houghton Mifflin', 279),
#              ('Washington Post', 277),
#              ('Category:British fantasy novels', 276),
#              ('History', 275),
#              ('Japan', 275),
#              ("Category:Children's historical novels", 274),
#              ('Little, Brown and Company', 274),
#              ('Category:2008 American novels', 273),
#              ('The Magazine of Fantasy  &  Science Fiction', 273),
#              ('Category:2003 books', 272),
#              ('E-book', 268),
#              ('William Morrow and Company', 266),
#              ('The Wall Street Journal', 264),
#              ('Earth', 263),
#              ('Hodder  &  Stoughton', 262),
#              ('Locus Award', 261),
#              ('Category:2005 American novels', 260),
#              ('Goodreads', 258),
#              ('Google Books', 257),
#              ('Category:2004 American novels', 255),
#              ('Category:Hodder  &  Stoughton books', 254),
#              ('DAW Books', 253),
#              ('American Civil War', 253),
#              ('San Francisco Chronicle', 249),
#              ('China', 249),
#              ('Category:2009 American novels', 249),
#              ('Category:American crime novels', 247),
#              ('Spanish language', 245),
#              ('Vietnam War', 244),
#              ('Category:English-language novels', 243),
#              ('Category:2010 American novels', 242),
#              ('Category:2003 American novels', 241),
#              ('Analog Science Fiction and Fact', 237),
#              ("Category:Children's science fiction novels", 237),
#              ('Chicago Tribune', 237),
#              ('Virgin Books', 236),
#              ('Anthony Boucher', 236),
#              ("Charles Scribner's Sons", 235),
#              ('Astounding Science Fiction', 235),
#              ('Cold War', 234),
#              ('Star Wars', 234),
#              ('picture book', 232),
#              ('President of the United States', 232),
#              ('Christianity', 231),
#              ('Category:Time travel novels', 230),
#              ('Adolf Hitler', 229),
#              ('Category:American horror novels', 228),
#              ('Germany', 227),
#              ('Audiobook', 227),
#              ('England', 226),
#              ('Category:2001 American novels', 225),
#              ('P. Schuyler Miller', 225),
#              ('Category:Heinemann (publisher) books', 225),
#              ('Advent (publisher)', 224),
#              ('Category:DAW Books books', 223),
#              ('Horror novel', 223),
#              ('William Shakespeare', 222),
#              ('Category:Little, Brown and Company books', 221),
#              ('Cambridge University Press', 218),
#              ('Category:2012 non-fiction books', 218),
#              ('Faber and Faber', 218),
#              ('Category:Books adapted into films', 218),
#              ('Category:2002 American novels', 217),
#              ('Category:Philosophy books', 217),
#              ('California', 216),
#              ('Hugo Award', 216),
#              ('Locus (magazine)', 215),
#              ('Amazon Kindle', 215),
#              ('Category:American memoirs', 215),
#              ('Category:Ballantine Books books', 215),
#              ('Category:2011 American novels', 213),
#              ('Category:American biographies', 213),
#              ('Category:Faber and Faber books', 211),
#              ('Egypt', 210),
#              ('Variety (magazine)', 210),
#              ('alternate history', 209),
#              ('Category:Essay collections', 209),
#              ('Category:2001 books', 209),
#              ('Los Angeles', 208),
#              ('New York Times Best Seller list', 208),
#              ('Pulitzer Prize', 207),
#              ('Baen Books', 207),
#              ('Category:American mystery novels', 206),
#              ('Farrar, Straus and Giroux', 206),
#              ('historical fiction', 205),
#              ('The New York Review of Books', 203),
#              ('Category:Houghton Mifflin books', 203),
#              ('Nebula Award', 202),
#              ('Scholastic Corporation', 202),
#              ('Berkley Books', 202),
#              ('Penguin Group', 201),
#              ('Stephen King', 201),
#              ('Category:British young adult novels', 201),
#              ('Category:1999 American novels', 198),
#              ('Robert E. Howard', 198),
#              ('Italy', 197),
#              ('F & SF', 197),
#              ('Category:French novels adapted into films', 196),
#              ('Arkham House', 196),
#              ('Sigmund Freud', 195),
#              ('The Spectator', 195),
#              ('Category:Thriller novels', 194),
#              ('Robert Silverberg', 194),
#              ('W. W. Norton  &  Company', 194),
#              ('H. G. Wells', 194),
#              ('Hamish Hamilton', 193),
#              ('Bloomsbury Publishing', 191),
#              ('Category:2002 books', 191),
#              ('Category:Novels set in California', 191),
#              ('Italian language', 191),
#              ('Category:1999 books', 190),
#              ('New Statesman', 190),
#              ('Pennsylvania', 190),
#              ('Category:Science fiction short story collections', 190),
#              ('Second World War', 189),
#              ('Category:Novels set in schools', 189),
#              ('Category:Simon  &  Schuster books', 188),
#              ('Category:2012 American novels', 188),
#              ('Category:1998 books', 188),
#              ('crime novel', 186),
#              ('Newbery Medal', 185),
#              ('Associated Press', 185),
#              ('Portuguese language', 185),
#              ('Grosset  &  Dunlap', 185),
#              ('Category:2000 American novels', 184),
#              ('Financial Times', 184),
#              ('pseudonym', 184),
#              ('Chicago', 184),
#              ('The Times Literary Supplement', 184),
#              ('TARDIS', 184),
#              ('William Collins, Sons', 183),
#              ('satire', 182),
#              ('The Economist', 181),
#              ("Category:Children's novels about animals", 181),
#              ('Russia', 181),
#              ('Bible', 181),
#              ('Philosophy', 181),
#              ('Category:Novels about orphans', 181),
#              ('Category:2014 books', 180),
#              ('Wizards of the Coast', 180),
#              ('The Boston Globe', 179),
#              ('Category:Single-writer short story collections', 179),
#              ('Amazing Stories', 179),
#              ('Category:2000 books', 179),
#              ('Israel', 179),
#              ('Ray Bradbury', 178),
#              ('Sherlock Holmes', 178),
#              ('Poul Anderson', 178),
#              ('book', 178),
#              ('H. P. Lovecraft', 177),
#              ('Mexico', 177),
#              ('File:', 177),
#              ('Boston', 177),
#              ('Arthur C. Clarke', 177),
#              ('Category:Fantasy anthologies', 177),
#              ('Hugo Award for Best Novel', 176),
#              ('Charles Dickens', 175),
#              ('Islam', 175),
#              ('Category:1998 American novels', 175),
#              ('Japanese language', 174),
#              ('Hutchinson (publisher)', 174),
#              ('Scholastic Press', 174),
#              ('Brazil', 173),
#              ('Category:2015 non-fiction books', 173),
#              ('Category:Macmillan Publishers books', 173),
#              ('Nazi Germany', 173),
#              ('Category:Political books', 171),
#              ('Category:American political books', 171),
#              ('Category:Literature featuring anthropomorphic characters', 170),
#              ('Category:1995 books', 170),
#              ('Latin', 170),
#              ('Category:Novels about writers', 170),
#              ('Great Depression', 169),
#              ('The Sunday Times', 168),
#              ('Target Books', 168),
#              ('San Francisco', 167),
#              ('Edgar Rice Burroughs', 167),
#              ('hardback', 167),
#              ('Dutch language', 167),
#              ('Heinemann (book publisher)', 167),
#              ('detective fiction', 167),
#              ('Dell Publishing', 166),
#              ('The New Republic', 166),
#              ('mystery novel', 166),
#              ('Category:Dungeons  &  Dragons sourcebooks', 166),
#              ('Category:Hutchinson (publisher) books', 166),
#              ('Theodore Sturgeon', 164),
#              ('List of Doctor Who novelisations', 164),
#              ('Category:1996 American novels', 163),
#              ('Picture book', 163),
#              ('Pittsburgh', 163),
#              ('Category:1997 books', 163),
#              ('suicide', 163),
#              ('Routledge', 163),
#              ('Charles Darwin', 163),
#              ('Young adult literature', 162),
#              ('James Joyce', 162),
#              ('evolution', 162),
#              ('Category:2007 British novels', 161),
#              ('graphic novel', 161),
#              ('Category:French-language novels', 160),
#              ('first-person narrative', 160),
#              ('The A.V. Club', 159),
#              ('horror fiction', 159),
#              ('Karl Marx', 159),
#              ('The Globe and Mail', 159),
#              ('Category:1996 books', 159),
#              ('Nebula Award for Best Novel', 159),
#              ('Fritz Leiber', 159),
#              ('biography', 158),
#              ('Category:1994 American novels', 158),
#              ('Category:American autobiographies', 158),
#              ('National Book Award', 158),
#              ('Barnes  &  Noble', 158),
#              ('sword and sorcery', 158),
#              ('Heinemann (publisher)', 158),
#              ('Lin Carter', 158),
#              ('Weird Tales', 158),
#              ('Category:William Collins, Sons books', 158),
#              ('Washington, D.C.', 157),
#              ('Groff Conklin', 157),
#              ('crime fiction', 156),
#              ('Category:2006 British novels', 155),
#              ('Category:2013 non-fiction books', 155),
#              ('Harper  &  Row', 155),
#              ('Central Intelligence Agency', 155),
#              ('science fiction television', 155),
#              ('Poetry', 154),
#              ('Robert A. Heinlein', 154),
#              ('The Hollywood Reporter', 154),
#              ('Bildungsroman', 154),
#              ('Category:Novels set in Paris', 153),
#              ('Category:American short story collections', 153),
#              ('Category:2015 American novels', 153),
#              ('Category:Books about politics of the United States', 153),
#              ('Category:1997 American novels', 153),
#              ('Carnegie Medal (literary award)', 153),
#              ('Princeton University Press', 153),
#              ('philosophy', 153),
#              ('Category:American alternate history novels', 153),
#              ('Category:1995 American novels', 153),
#              ('Star Wars canon', 153),
#              ('Category:American poetry collections', 152),
#              ('The Sydney Morning Herald', 152),
#              ('Category:Self-help books', 152),
#              ('Category:Sociology books', 152),
#              ('CNN', 152),
#              ('Category:Chatto  &  Windus books', 151),
#              ('Category:1993 American novels', 151),
#              ('Mars', 151),
#              ('Delacorte Press', 151),
#              ('Nobel Prize in Literature', 151),
#              ('Dragon (magazine)', 151),
#              ('Category:Business books', 151),
#              ('Ursula K. Le Guin', 151),
#              ('Philip K. Dick', 150),
#              ('Category:Young adult fantasy novels', 150),
#              ('Edgar Allan Poe', 150),
#              ('Category:Novels published posthumously', 150),
#              ('Category:2014 non-fiction books', 149),
#              ('God', 149),
#              ('VHS', 149),
#              ('Category:2013 American novels', 148),
#              ('Harper Collins', 147),
#              ('Philippines', 147),
#              ('Newsweek', 147),
#              ('AustLit', 147),
#              ('Agatha Christie', 147),
#              ('Category:W. W. Norton  &  Company books', 147),
#              ('Category:Metafictional novels', 146),
#              ('Spy novel', 146),
#              ('Serial (literature)', 145),
#              ('author', 145),
#              ('Category:Crime novels', 145),
#              ('Harvard University', 144),
#              ('Wall Street Journal', 144),
#              ('Category:Novels set in Los Angeles', 144),
#              ('Rome', 143),
#              ('psychology', 143),
#              ('Puffin Books', 143),
#              ('Category:Literary collaborations', 143),
#              ('Little, Brown', 143),
#              ('Forgotten Realms', 142),
#              ('Category:1991 books', 142),
#              ('Library of Congress', 142),
#              ('Category:2016 non-fiction books', 142),
#              ('Collins Crime Club', 142),
#              ('Category:2014 American novels', 141),
#              ('Polish language', 140),
#              ('Category:Novels with gay themes', 140),
#              ('Radio Times', 140),
#              ('Iran', 139),
#              ("Category:Children's fiction books", 139),
#              ('Paperback#Trade paperback', 139),
#              ('fantasy literature', 138),
#              ('Damon Knight', 138),
#              ('Man Booker Prize', 138),
#              ('Category:American romance novels', 138),
#              ('Category:Victor Gollancz Ltd books', 138),
#              ('Category:Articles created via the Article Wizard', 137),
#              ('Vintage Books', 136),
#              ('South Africa', 136),
#              ('First World War', 136),
#              ('Victorian era', 135),
#              ('Orson Scott Card', 135),
#              ('The Atlantic', 135),
#              ('Category:Popular science books', 135),
#              ('National Review', 135),
#              ('Category:1992 books', 135),
#              ('Jesus', 134),
#              ('Ireland', 134),
#              ('Category:20th-century history books', 134),
#              ('Africa', 134),
#              ('Category:2005 British novels', 134),
#              ('Category:Novels set on islands', 134),
#              ('Arthur Conan Doyle', 134),
#              ('Science Fiction', 133),
#              ('New York Times Book Review', 133),
#              ('Nonfiction', 133),
#              ('time travel', 133),
#              ('Orbit Books', 132),
#              ('Category:1988 American novels', 132),
#              ('homosexuality', 132),
#              ('Seventh Doctor', 132),
#              ('Doctor Who Magazine', 132),
#              ('Pantheon Books', 131),
#              ('Category:American LGBT novels', 131),
#              ('Category:Harper  &  Brothers books', 131),
#              ('Category:Hamish Hamilton books', 130),
#              ('Category:1991 American novels', 130),
#              ('Thriller novel', 130),
#              ('Category:Novels set in New York (state)', 130),
#              ('Holocaust', 130),
#              ('Mark Twain', 130),
#              ('DVD', 130),
#              ('Category:1992 American novels', 130),
#              ('Plato', 130),
#              ('Alternate history', 129),
#              ('Frederik Pohl', 129),
#              ('Barack Obama', 129),
#              ('Joseph Stalin', 129),
#              ('George W. Bush', 129),
#              ('Times Literary Supplement', 129),
#              ('Category:2006 novels', 129),
#              ('British Empire', 129),
#              ('Chatto  &  Windus', 128),
#              ('Category:Novels set in France', 128),
#              ('Category:Harper  &  Row books', 128),
#              ('Category:American novellas', 128),
#              ('Category:2017 non-fiction books', 128),
#              ('Category:1990 American novels', 127),
#              ('Harvard University Press', 127),
#              ('J. R. R. Tolkien', 127),
#              ('Category:1994 books', 127),
#              ('Gardner Dozois', 127),
#              ('Henry James', 127),
#              ('Satire', 127),
#              ('detective novel', 127),
#              ('young adult novel', 127),
#              ('The Encyclopedia of Science Fiction', 127),
#              ('Category:2003 British novels', 126),
#              ('Henry Holt and Company', 126),
#              ('Bill Clinton', 126),
#              ('adventure novel', 126),
#              ("children's book", 126),
#              ('essay', 126),
#              ('Europe', 125),
#              ('Category:Newbery Honor-winning works', 125),
#              ('Big Finish Productions', 125),
#              ('The Huffington Post', 125),
#              ('Category:History books about the United States', 125),
#              ('Category:1987 American novels', 125),
#              ('Fourth Doctor', 125),
#              ('Pakistan', 124),
#              ('Gothic fiction', 124),
#              ('Jules Verne', 124),
#              ('Category:William Morrow and Company books', 124),
#              ('Winston Churchill', 124),
#              ('August Derleth', 124),
#              ('Booker Prize', 123),
#              ('Aristotle', 123),
#              ('Harper (publisher)', 123),
#              ('George Orwell', 123),
#              ('Category:Single-writer horror short story collections', 123),
#              ('J. Francis McComas', 123),
#              ('Category:Contemporary philosophical literature', 122),
#              ('Category:Horror novels', 122),
#              ('FBI', 122),
#              ('Chinese language', 122),
#              ('Category:2008 British novels', 122),
#              ('Category:1989 American novels', 122),
#              ('Category:Swedish-language novels', 122),
#              ('Conan the Barbarian', 122),
#              ('National Book Critics Circle Award', 121),
#              ('Printing', 121),
#              ('United States of America', 121),
#              ('Category:2002 British novels', 121),
#              ('Finland', 121),
#              ('National Book Foundation', 121),
#              ('Category:1984 American novels', 120),
#              ("Children's novel", 120),
#              ('Spain', 120),
#              ('Category:1989 books', 120),
#              ('Category:2004 British novels', 120),
#              ('Category:2008 novels', 120),
#              ('Slovenia', 120),
#              ('Category:Grosset  &  Dunlap books', 120),
#              ('Eighth Doctor', 120),
#              ('Edgar Award', 119),
#              ('Abraham Lincoln', 119),
#              ('Christian', 119),
#              ('Moscow', 119),
#              ('Category:Techno-thriller novels', 119),
#              ('science fantasy', 119),
#              ('Category:Novels set in India', 118),
#              ('YouTube', 118),
#              ('French Revolution', 118),
#              ('Category:1993 books', 118),
#              ('September 11 attacks', 118),
#              ('capitalism', 117),
#              ('Short story', 117),
#              ('Category:Novels set in England', 117),
#              ('Greece', 117),
#              ('poetry', 116),
#              ('Middle Ages', 116),
#              ('Marxism', 116),
#              ('Roger Zelazny', 116),
#              ('Category:1985 American novels', 116),
#              ("Don D'Ammassa", 116),
#              ('Category:2001 British novels', 116),
#              ('University of Chicago Press', 115),
#              ('Nazism', 115),
#              ('Category:British historical novels', 115),
#              ('Category:American history books', 115),
#              ('Angus and Robertson', 115),
#              ('racism', 114),
#              ('Manhattan', 114),
#              ('artificial intelligence', 114),
#              ('Age of Enlightenment', 114),
#              ('Rolling Stone', 114),
#              ('Category:Travel books', 114),
#              ('Category:1999 British novels', 114),
#              ('bestseller', 114),
#              ('Yale University Press', 114),
#              ('Category:1982 American novels', 113),
#              ('Category:2004 novels', 113),
#              ('CIA', 113),
#              ('Harper  &  Brothers', 113),
#              ('London Review of Books', 113),
#              ('Category:Postmodern novels', 113),
#              ('Texas', 113),
#              ('C-SPAN', 112),
#              ('Caldecott Medal', 112),
#              ('vampire', 112),
#              ('dystopia', 112),
#              ('Harry Turtledove', 112),
#              ('Category:World War I novels', 112),
#              ('Columbia University', 111),
#              ('Methuen Publishing', 111),
#              ('Switzerland', 111),
#              ('Category:2005 novels', 111),
#              ('Wikipedia:WikiProject Novels/Novel categorization', 111),
#              ('BBC1', 111),
#              ('Category:Farrar, Straus and Giroux books', 110),
#              ('Category:Henry Holt and Company books', 110),
#              ('Category:2016 American novels', 110),
#              ('Berlin', 110),
#              ('Florida', 110),
#              ('Category:2009 British novels', 110),
#              ('Pan Books', 110),
#              ('Category:Science books', 110),
#              ('Avon Books', 110),
#              ('Crown Publishing Group', 110),
#              ('Philadelphia', 110),
#              ('War novel', 110),
#              ('public domain', 110),
#              ('Category:1986 books', 109),
#              ('Ancient Rome', 109),
#              ('Category:British mystery novels', 109),
#              ('Category:Novels set in San Francisco', 109),
#              ('Denmark', 109),
#              ('Category:21st-century history books', 109),
#              ('Éditions Gallimard', 109),
#              ('Category:2000 novels', 109),
#              ('Future plc', 109),
#              ('Poland', 109),
#              ('National Public Radio', 109),
#              ('Algis Budrys', 109),
#              ('Category:Fiction with unreliable narrators', 109),
#              ('The Nation', 108),
#              ('Friedrich Nietzsche', 108),
#              ('Turkey', 108),
#              ('Category:Epistolary novels', 108),
#              ('Category:1988 books', 108),
#              ('Daily Mail', 108),
#              ('encyclopedia', 108),
#              ('American literature', 108),
#              ('Modern Library', 108),
#              ('Category:African-American novels', 107),
#              ('BBC News', 107),
#              ('Category:1990 books', 107),
#              ('feminism', 107),
#              ('Houghton Mifflin Harcourt', 107),
#              ('Michiko Kakutani', 107),
#              ('Shakespeare', 107),
#              ('Third Doctor', 107),
#              ('Finnish language', 107),
#              ('Roman Empire', 107),
#              ('parody', 107),
#              ('romance novel', 107),
#              ('Hollywood', 107),
#              ('Category:1986 American novels', 107),
#              ('Category:Slovenian novels', 107),
#              ('Category:Oxford University Press books', 106),
#              ('Spy fiction', 106),
#              ('New American Library', 106),
#              ('Category:1985 books', 106),
#              ('King Arthur', 106),
#              ('Category:Post-apocalyptic novels', 106),
#              ('Slovenian language', 106),
#              ('The Scotsman', 105),
#              ('Vienna', 105),
#              ('Esquire (magazine)', 105),
#              ('Immanuel Kant', 105),
#              ('religion', 105),
#              ('Bantam Spectra', 105),
#              ('Virgin New Adventures', 105),
#              ('Category:2003 novels', 104),
#              ('Rudyard Kipling', 104),
#              ('Slate (magazine)', 104),
#              ('Category:2007 novels', 104),
#              ('Franz Kafka', 104),
#              ('Category:Environmental non-fiction books', 104),
#              ('Michael Moorcock', 104),
#              ('Salon.com', 104),
#              ('Romanticism', 104),
#              ('Warner Books', 104),
#              ('The Discontinuity Guide', 104),
#              ('The Hindu', 103),
#              ('Russian Empire', 103),
#              ('sequel', 103),
#              ('Category:American autobiographical novels', 103),
#              ('Category:Psychology books', 103),
#              ('Category:Novels set in Pittsburgh', 103),
#              ('Grove Press', 103),
#              ('Jack Vance', 103),
#              ('Category:Berkley Books books', 103),
#              ('Category:Books published posthumously', 102),
#              ('Bernice Summerfield', 102),
#              ('Venice', 102),
#              ('Neil Gaiman', 102),
#              ('Ernest Hemingway', 102),
#              ('Dodd, Mead and Company', 102),
#              ('Category:Novels set on fictional planets', 102),
#              ('L. Frank Baum', 102),
#              ('John F. Kennedy', 101),
#              ('Ronald Reagan', 101),
#              ("Category:2006 children's books", 101),
#              ('Category:1983 American novels', 101),
#              ('Category:Romance novels', 101),
#              ('Category:Physics books', 101),
#              ('Lake Geneva, Wisconsin', 101),
#              ('Paramount Pictures', 101),
#              ('copyright', 101),
#              ('James Bond', 101),
#              ('List of Slovenian novels', 101),
#              ('Category:1981 American novels', 100),
#              ('Deadline Hollywood', 100),
#              ('Category:Mars in fiction', 100),
#              ('Virginia', 100),
#              ('Travel literature', 100),
#              ('Netherlands', 100),
#              ("Category:2007 children's books", 100),
#              ('Nazi', 100),
#              ('New Orleans', 99),
#              ('Boston Globe', 99),
#              ('Ottoman Empire', 99),
#              ('Honoré de Balzac', 99),
#              ('New York (state)', 99),
#              ('First Doctor', 99),
#              ('E. P. Dutton', 99),
#              ('Larry Niven', 99),
#              ('fiction', 99),
#              ('John Clute', 99),
#              ('Toronto', 99),
#              ('Afghanistan', 99),
#              ('Gene Wolfe', 99),
#              ('Norwegian language', 99),
#              ('Vladimir Nabokov', 99),
#              ('Donald M. Grant, Publisher, Inc.', 99),
#              ('Hungary', 98),
#              ('Category:1998 novels', 98),
#              ('Category:1979 books', 98),
#              ('Middle East', 98),
#              ('Toronto Star', 98),
#              ('Allen  &  Unwin', 98),
#              ("Category:Children's short story collections", 98),
#              ('NBC', 98),
#              ('First-person narrative', 98),
#              ('Albert Einstein', 97),
#              ('Adventure fiction', 97),
#              ('Category:1999 novels', 97),
#              ('Orion Publishing Group', 97),
#              ('If (magazine)', 97),
#              ('CBS', 97),
#              ('Cuba', 97),
#              ('White House', 97),
#              ('United Nations', 97),
#              ('Tor.com', 96),
#              ('Category:1984 books', 96),
#              ('Category:1998 British novels', 96),
#              ('Buddhism', 96),
#              ('Warner Bros.', 96),
#              ('Category:1997 novels', 96),
#              ('Category:Anthony Award-winning works', 96),
#              ('Martin H. Greenberg', 96),
#              ('2006 in literature', 95),
#              ('slavery', 95),
#              ('Category:American bildungsromans', 95),
#              ('amazon.com', 95),
#              ('trilogy', 95),
#              ('Terry Pratchett', 95),
#              ('Harlan Ellison', 95),
#              ('Jerusalem', 95),
#              ('Jane Austen', 95),
#              ('Lewis Carroll', 95),
#              ('Category:Novels set in Japan', 95),
#              ('Category:Rape in fiction', 95),
#              ('Faber  &  Faber', 95),
#              ('Category:Star Wars Legends novels', 95),
#              ('Nature (journal)', 94),
#              ('Paul Cornell', 94),
#              ('Hodder and Stoughton', 94),
#              ('Picador (imprint)', 94),
#              ('Bengali language', 94),
#              ('Category:Aviation novels', 94),
#              ('Category:2000 British novels', 94),
#              ('A. E. van Vogt', 94),
#              ('Category:1973 books', 94),
#              ('Iraq War', 94),
#              ('Category:Victorian novels', 94),
#              ('Category:Newbery Medal-winning works', 94),
#              ('Category:2001 novels', 94),
#              ('Gnome Press', 94),
#              ('Terrance Dicks', 94),
#              ('Franklin W. Dixon', 94),
#              ('Category:Western (genre) novels', 93),
#              ('Short stories', 93),
#              ('Scotland', 93),
#              ('Category:Family saga novels', 93),
#              ('Miles Franklin Award', 93),
#              ('Massachusetts', 93),
#              ('University of Oxford', 93),
#              ('Category:1979 American novels', 93),
#              ('Category:Novels set in Scotland', 93),
#              ('Category:Works originally published in Analog Science Fiction and Fact',
#               93),
#              ('Category:The Hardy Boys books', 93),
#              ('Second Doctor', 93),
#              ('comic book', 92),
#              ('Catholic Church', 92),
#              ('Parallel universe (fiction)', 92),
#              ('Psychology', 92),
#              ('Category:British comedy novels', 92),
#              ('Category:Modern Arthurian fiction', 92),
#              ('Playboy', 92),
#              ('Category:1981 books', 92),
#              ('CILIP', 92),
#              ('democracy', 92),
#              ('Persian language', 91),
#              ('United States Army', 91),
#              ('Michael Joseph (publisher)', 91),
#              ('Henry Kuttner', 91),
#              ('Category:American post-apocalyptic novels', 91),
#              ('Category:German-language novels', 91),
#              ('young adult literature', 91),
#              ('Category:1983 books', 91),
#              ('Science fantasy', 91),
#              ('The Lord of the Rings', 90),
#              ('Politics', 90),
#              ('New Scientist', 90),
#              ('The Christian Science Monitor', 90),
#              ('University of California Press', 90),
#              ('Daily Telegraph', 90),
#              ('Muslim', 90),
#              ('Richard Dawkins', 90),
#              ('Science', 90),
#              ('Belgium', 90),
#              ('Lester del Rey', 90),
#              ('Category:1974 American novels', 90),
#              ('Category:1980 American novels', 90),
#              ('Jewish', 90),
#              ('Arabic language', 89),
#              ('Republican Party (United States)', 89),
#              ('Princeton University', 89),
#              ('Category:History books about World War II', 89),
#              ('New England', 89),
#              ('telepathy', 89),
#              ('Virginia Woolf', 89),
#              ('Harcourt (publisher)', 89),
#              ('Stephen Baxter (author)', 89),
#              ('horror novel', 89),
#              ('Category:1996 British novels', 89),
#              ('Weidenfeld  &  Nicolson', 89),
#              ('Category:1997 British novels', 89),
#              ('journalist', 89),
#              ("children's novel", 89),
#              ('Jesus Christ', 89),
#              ('Category:Non-fiction crime books', 89),
#              ('Clark Ashton Smith', 89),
#              ('Category:Australian young adult novels', 88),
#              ('Softcover', 88),
#              ('Austria', 88),
#              ('Novella', 88),
#              ('Iraq', 88),
#              ('Grand Central Publishing', 88),
#              ('Category:Space exploration novels', 88),
#              ('Basic Books', 88),
#              ('HighBeam Research', 88),
#              ('Category:1987 books', 88),
#              ('Category:Novels about artists', 88),
#              ('Category:American vampire novels', 88),
#              ('English people', 88),
#              ('Sword and sorcery', 88),
#              ('Category:Satirical novels', 88),
#              ('Astounding', 88),
#              ('Category:Anthropology books', 87),
#              ('tuberculosis', 87),
#              ('Category:1972 books', 87),
#              ('Category:Novels set in China', 87),
#              ('ITV (TV network)', 87),
#              ('Category:2009 novels', 86),
#              ('history', 86),
#              ('Category:Forgotten Realms novels', 86),
#              ('Category:Feminist books', 86),
#              ('Category:1995 British novels', 86),
#              ('prequel', 86),
#              ('Category:British picture books', 86),
#              ('rape', 86),
#              ('Category:Space opera novels', 86),
#              ('Category:British crime novels', 86),
#              ('C. S. Lewis', 86),
#              ('Category:1980 books', 86),
#              ('Indigenous peoples of the Americas', 86),
#              ('Voltaire', 86),
#              ('Native Americans in the United States', 86),
#              ('Category:Methuen Publishing books', 86),
#              ('psychoanalysis', 85),
#              ('Great Britain', 85),
#              ('Category:2010 British novels', 85),
#              ('Category:Music autobiographies', 85),
#              ('Academy Award', 85),
#              ('Category:1975 books', 85),
#              ('anthropology', 85),
#              ('Category:Comedy books', 85),
#              ('Murray Leinster', 85),
#              ('Federal Bureau of Investigation', 85),
#              ('File:Example.jpg', 85),
#              ("Category:2004 children's books", 85),
#              ('serial killer', 85),
#              ('Category:Picaresque novels', 85),
#              ('allegory', 85),
#              ('Dean Koontz', 85),
#              ('Past Doctor Adventures', 85),
#              ('Category:Novels set in the 19th century', 84),
#              ('Edinburgh', 84),
#              ('Category:American comedy novels', 84),
#              ('New York Public Library', 84),
#              ('dragon', 84),
#              ('Julius Caesar', 84),
#              ('Argentina', 84),
#              ("Category:G. P. Putnam's Sons books", 84),
#              ('Category:1971 American novels', 84),
#              ('Category:American political novels', 84),
#              ('Fawcett Publications', 84),
#              ('science', 84),
#              ('Internet Movie Database', 84),
#              ('Comic novel', 84),
#              ('Nebula Award for Best Novelette', 84),
#              ('Category:2017 American novels', 84),
#              ('Category:1976 books', 84),
#              ("Harper's Magazine", 84),
#              ('Oscar Wilde', 84),
#              ('Category:Novels set in Florida', 84),
#              ('Category:1982 books', 83),
#              ("Category:St. Martin's Press books", 83),
#              ('Category:20th-century Indian novels', 83),
#              ('Royal Navy', 83),
#              ('Speculative fiction', 83),
#              ('Frank Herbert', 83),
#              ('Category:1971 books', 83),
#              ('Christmas', 83),
#              ('James Patterson', 83),
#              ('Pulitzer Prize for Fiction', 83),
#              ('Autobiographical novel', 83),
#              ('Category:1977 books', 83),
#              ('HBO', 83),
#              ('Hamlet', 83),
#              ('Graham Greene', 83),
#              ('H. Rider Haggard', 83),
#              ('Category:Virgin New Adventures', 83),
#              ('ebook', 82),
#              ('Oxford', 82),
#              ('autobiographical novel', 82),
#              ('Twitter', 82),
#              ('Napoleon', 82),
#              ('Jean-Paul Sartre', 82),
#              ('Dublin', 82),
#              ("Category:2008 children's books", 82),
#              ('Category:Caldecott Medal-winning works', 82),
#              ('Category:1998 science fiction novels', 82),
#              ('Samuel R. Delany', 82),
#              ('KGB', 82),
#              ('Michael Whelan', 82),
#              ('T. S. Eliot', 82),
#              ('Category:High fantasy novels', 82),
#              ('Eighth Doctor Adventures', 82),
#              ('sociology', 81),
#              ('Renaissance', 81),
#              ('Democratic Party (United States)', 81),
#              ('Category:Novels set in Germany', 81),
#              ('Fantasy and Science Fiction', 81),
#              ('goodreads.com', 81),
#              ('Danish language', 81),
#              ('Category:1972 American novels', 81),
#              ('Salon (website)', 81),
#              ('Category:1978 American novels', 81),
#              ('epistolary novel', 81),
#              ('Category:2008 science fiction novels', 81),
#              ...])

# %%
# list tuples
list(wikilink_counts.items())[:10]
# Out:
# [('Hardcover', 7489),
#  ('Paperback', 7311),
#  ('Wikipedia:WikiProject Books', 6043),
#  ('Wikipedia:WikiProject Novels', 6015),
#  ('English language', 4185),
#  ('United States', 3060),
#  ('Science fiction', 3030),
#  ('The New York Times', 2727),
#  ('science fiction', 2502),
#  ('novel', 1979)]

# %%
# 将字符转小写 
wikilinks = [link.lower() for link in unique_wikilinks]
print(f"There are {len(set(wikilinks))} unique wikilinks.")
# Out:
# There are 297624 unique wikilinks.

# %%
wikilink_counts = count_items(wikilinks)
list(wikilink_counts.items())[:10]
# Out:
# [('paperback', 8740),
#  ('hardcover', 8648),
#  ('wikipedia:wikiproject books', 6043),
#  ('wikipedia:wikiproject novels', 6016),
#  ('science fiction', 5665),
#  ('english language', 4248),
#  ('united states', 3063),
#  ('novel', 2983),
#  ('the new york times', 2742),
#  ('fantasy', 2003)]

# %%
# TF_IDF 计算

# %%
to_remove = ['hardcover', 'paperback', 'hardback', 'e-book', 'wikipedia:wikiproject books', 'wikipedia:wikiproject novels']
for t in to_remove:
    wikilinks.remove(t)
    _ = wikilink_counts.pop(t)

# %%
# Limit to greater than 3 links
links = [t[0] for t in wikilink_counts.items() if t[1] >= 4]
print(len(links))
# Out:
# 41758
